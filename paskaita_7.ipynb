# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
df = pd.DataFrame({'col1': [1, 2], 'col2': [3, 4]})

# %%
df
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
df = pd.DataFrame( [ [1, 2], [3, 4] ], columns = [ 'col1', 'col2' ] ) # row values in a list [row_1_values, row_2_values,...]
df
# Out:
#    col1  col2
# 0     1     2
# 1     3     4

# %%
df = pd.DataFrame( { 'Age' : [20,30,40,25,55], 'Name': ["Bob", "Carl", "Tom", "Vycka", "John"]}, index = ['pirmas', 'two', 'tres', 'ketvirtas', 'paskutinis' ] )
df
# Out:
#             Age   Name
# pirmas       20    Bob
# two          30   Carl
# tres         40    Tom
# ketvirtas    25  Vycka
# paskutinis   55   John

# %%
df.index
# Out:
# Index(['pirmas', 'two', 'tres', 'ketvirtas', 'paskutinis'], dtype='object')

# %%
df.columns
# Out:
# Index(['Age', 'Name'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, pirmas to paskutinis
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     5 non-null      int64
#  1   Name    5 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 80.0+ bytes

# %%
series = df['Age']
series
# Out:
# pirmas        20
# two           30
# tres          40
# ketvirtas     25
# paskutinis    55
# Name: Age, dtype: int64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\vytau\\Documents\\Python_mokymai'

# %%
wine_df = pd.read_csv('winemag-data.csv', index_col = 0) # relative path
wine_df
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
wine_df.to_excel('wine.xlsx', engine )

# %%
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129971 entries, 0 to 129970
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   country                129908 non-null  object
#  1   description            129971 non-null  object
#  2   designation            92506 non-null   object
#  3   points                 129971 non-null  int64
#  4   price                  120975 non-null  float64
#  5   province               129908 non-null  object
#  6   region_1               108724 non-null  object
#  7   region_2               50511 non-null   object
#  8   taster_name            103727 non-null  object
#  9   taster_twitter_handle  98758 non-null   object
#  10  title                  129971 non-null  object
#  11  variety                129970 non-null  object
#  12  winery                 129971 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 8.4+ MB

# %%
wine_df.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
wine_df.tail()
# Out:
#         country                                        description  \
# 129966  Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967       US  Citation is given as much as a decade of bottl...
# 129968   France  Well-drained gravel soil gives this wine its c...
# 129969   France  A dry style of Pinot Gris, this is crisp with ...
# 129970   France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price province  \
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0    Mosel
# 129967                                     NaN      90   75.0   Oregon
# 129968                                   Kritt      90   30.0   Alsace
# 129969                                     NaN      90   32.0   Alsace
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
#        region_1      region_2         taster_name taster_twitter_handle  \
# ...

# %%
print(set(wine_df['country']))
# Out:
# {nan, 'Lebanon', 'New Zealand', 'England', 'France', 'Slovenia', 'Austria', 'Chile', 'Morocco', 'Luxembourg', 'Mexico', 'India', 'South Africa', 'Slovakia', 'Egypt', 'Georgia', 'Macedonia', 'Greece', 'Switzerland', 'Bosnia and Herzegovina', 'Ukraine', 'Canada', 'Argentina', 'Romania', 'Turkey', 'Moldova', 'Cyprus', 'Serbia', 'Portugal', 'US', 'Brazil', 'Australia', 'Bulgaria', 'Spain', 'Czech Republic', 'Italy', 'Croatia', 'Peru', 'Israel', 'Hungary', 'China', 'Armenia', 'Germany', 'Uruguay'}

# %%
print(type(pd.NA))
print(pd.NA == None)
# Out:
# <class 'pandas._libs.missing.NAType'>
# False

# %%
wine_df.describe()
# Out:
#               points          price
# count  129971.000000  120975.000000
# mean       88.447138      35.363389
# std         3.039730      41.022218
# min        80.000000       4.000000
# 25%        86.000000      17.000000
# 50%        88.000000      25.000000
# 75%        91.000000      42.000000
# max       100.000000    3300.000000

# %%
wine_df.describe(include = 'all')
# Out:
#        country                                        description designation  \
# count   129908                                             129971       92506
# unique      43                                             119955       37979
# top         US  This zesty red has pretty aromas that suggest ...     Reserve
# freq     54504                                                  3        2009
# mean       NaN                                                NaN         NaN
# std        NaN                                                NaN         NaN
# min        NaN                                                NaN         NaN
# 25%        NaN                                                NaN         NaN
# 50%        NaN                                                NaN         NaN
# 75%        NaN                                                NaN         NaN
# max        NaN                                                NaN         NaN
#
# ...

# %% [markdown]
# ## Pandas duomenu filravimas

# %%
wine_df['country']
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
wine_df.country
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
wine_df[ ['country', 'province'] ]
# Out:
#          country           province
# 0          Italy  Sicily & Sardinia
# 1       Portugal              Douro
# 2             US             Oregon
# 3             US           Michigan
# 4             US             Oregon
# ...          ...                ...
# 129966   Germany              Mosel
# 129967        US             Oregon
# 129968    France             Alsace
# 129969    France             Alsace
# 129970    France             Alsace
#
# [129971 rows x 2 columns]

# %%
wine_df[ 'country', 'province' ] ## error!!!!!!!!!

# %%
wine_df[ 'country' ][0]
# Out:
# 'Italy'

# %%
wine_df['description'][0].split()
# Out:
# ['Aromas',
#  'include',
#  'tropical',
#  'fruit,',
#  'broom,',
#  'brimstone',
#  'and',
#  'dried',
#  'herb.',
#  'The',
#  'palate',
#  "isn't",
#  'overly',
#  'expressive,',
#  'offering',
#  'unripened',
#  'apple,',
#  'citrus',
#  'and',
#  'dried',
#  'sage',
#  'alongside',
#  'brisk',
#  'acidity.']

# %% [markdown]
# ### iloc

# %%
wine_df.iloc[0] # gives first row in the table, doesnt matter the index
# Out:
# country                                                              Italy
# description              Aromas include tropical fruit, broom, brimston...
# designation                                                   Vulkà Bianco
# points                                                                  87
# price                                                                  NaN
# province                                                 Sicily & Sardinia
# region_1                                                              Etna
# region_2                                                               NaN
# taster_name                                                  Kerin O’Keefe
# taster_twitter_handle                                         @kerinokeefe
# title                                    Nicosia 2013 Vulkà Bianco  (Etna)
# variety                                                        White Blend
# ...

# %%
wine_df.loc[0] # gives a row with the index zero!!!
# Out:
# country                                                              Italy
# description              Aromas include tropical fruit, broom, brimston...
# designation                                                   Vulkà Bianco
# points                                                                  87
# price                                                                  NaN
# province                                                 Sicily & Sardinia
# region_1                                                              Etna
# region_2                                                               NaN
# taster_name                                                  Kerin O’Keefe
# taster_twitter_handle                                         @kerinokeefe
# title                                    Nicosia 2013 Vulkà Bianco  (Etna)
# variety                                                        White Blend
# ...

# %%
sorted_df = wine_df.sort_index(level = 0, ascending=False)

# %%
sorted_countries_df = wine_df.set_index('country').sort_index(level = 'country')
#sorted_countries_df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\vytau\Documents\Python_mokymai\paskaita_7.ipynb Cell 33' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/vytau/Documents/Python_mokymai/paskaita_7.ipynb#ch0000033?line=0'>1</a> sorted_countries_df = wine_df.set_index('country').sort_index(level = 'country')
#
# File ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\frame.py:5433, in DataFrame.sort_index(self, axis, level, ascending, inplace, kind, na_position, sort_remaining, ignore_index, key)
#    <a href='file:///~/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/core/frame.py?line=5430'>5431</a> labels = labels._sort_levels_monotonic()
#    <a href='file:///~/AppData/Local/Programs/Python/Python38-32/lib/site-packages/pandas/core/frame.py?line=5431'>5432</a> if level is not None:
# ...

# %%
wine_df.loc[[5,44], ['points', 'price']]
# Out:
#     points  price
# 5       87   15.0
# 44      86    9.0

# %%
tmp_df = wine_df.set_index( 'province' )
tmp_df.head()
# Out:
#                     country  \
# province
# Sicily & Sardinia     Italy
# Douro              Portugal
# Oregon                   US
# Michigan                 US
# Oregon                   US
#
#                                                          description  \
# province
# Sicily & Sardinia  Aromas include tropical fruit, broom, brimston...
# Douro              This is ripe and fruity, a wine that is smooth...
# Oregon             Tart and snappy, the flavors of lime flesh and...
# Michigan           Pineapple rind, lemon pith and orange blossom ...
# Oregon             Much like the regular bottling from 2012, this...
#
#                                           designation  points  price  \
# province
# Sicily & Sardinia                        Vulkà Bianco      87    NaN
# Douro                                        Avidagos      87   15.0
# Oregon                                            NaN      87   14.0
# ...

# %%
tmp_df = tmp_df.reset_index()
tmp_df.head()
# Out:
#             province   country  \
# 0  Sicily & Sardinia     Italy
# 1              Douro  Portugal
# 2             Oregon        US
# 3           Michigan        US
# 4             Oregon        US
#
#                                          description  \
# 0  Aromas include tropical fruit, broom, brimston...
# 1  This is ripe and fruity, a wine that is smooth...
# 2  Tart and snappy, the flavors of lime flesh and...
# 3  Pineapple rind, lemon pith and orange blossom ...
# 4  Much like the regular bottling from 2012, this...
#
#                           designation  points  price             region_1  \
# 0                        Vulkà Bianco      87    NaN                 Etna
# 1                            Avidagos      87   15.0                  NaN
# 2                                 NaN      87   14.0    Willamette Valley
# 3                Reserve Late Harvest      87   13.0  Lake Michigan Shore
# 4  Vintner's Reserve Wild Child Block      87   65.0    Willamette Valley
#
# ...

# %% [markdown]
# ## Duomenu filtravimas pagal reiksmes

# %%
wine_df.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
wine_df['taster_name'] == "Roger Voss"
# Out:
# 0         False
# 1          True
# 2         False
# 3         False
# 4         False
#           ...
# 129966    False
# 129967    False
# 129968     True
# 129969     True
# 129970     True
# Name: taster_name, Length: 129971, dtype: bool

# %%
wine_df [(wine_df['country'] == 'Italy') & (wine_df['taster_name'] == 'Roger Voss') ]
# Out:
#        country                                        description  \
# 371      Italy  Fragrant, aromatic, grassy aromas give way to ...
# 372      Italy  A fresh, crisp style of Soave, brimming with g...
# 373      Italy  Crisp, green, grassy wine with fresh acidity a...
# 376      Italy  A well-judged, well-structured wine that balan...
# 384      Italy  Aromas of roses, pepper and spices make this a...
# ...        ...                                                ...
# 124826   Italy  Fresh, crisp, lightly grassy flavors make this...
# 125782   Italy  There is an amazing medley of aromas and flavo...
# 125791   Italy  This wine, which takes the family name of Fran...
# 127501   Italy  This is an elegant, smooth wine with fresh cle...
# 127505   Italy  A rich, complex style, with good concentration...
#
#                        designation  points  price            province  \
# 371                Castel Ringberg      88   23.0  Northeastern Italy
# ...

# %%
wine_df[ wine_df['country'].isin(['Italy', 'France']) & (wine_df['price'] < 6 )]
# Out:
#        country                                        description designation  \
# 3167     Italy  Packaged in a pocket-friendly 187-ml bottle, t...        Mini
# 5789    France  This is a jammy and fruit-forward selection, w...         NaN
# 5801    France  This blend of 70% Grenache and 30% Carignan is...         NaN
# 102853   Italy  Definitely not Zinfandel-like, despite its Pri...         NaN
# 102859   Italy  Terrale translates as “product of the earth,” ...      Bianco
# 102861   Italy  A thin peach nose is the initial impression, f...         NaN
# 105918  France  Smells a little warm with notes of stewed red ...         NaN
# 122407  France  This blend of Sauvignon Blanc and Grenache Bla...         NaN
#
#         points  price              province          region_1 region_2  \
# 3167        86    5.0                Veneto          Prosecco      NaN
# 5789        83    5.0          France Other     Vin de France      NaN
# ...

# %%
wine_df['points'].max()
# Out:
# 100

# %%
wine_df[ wine_df['country'].isin(['Italy', 'France']) & ((wine_df['price'] < 6 ) | (~wine_df['price'].notna())) ]
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 13       Italy  This is dominated by oak and oak-driven aromas...
# 30      France  Red cherry fruit comes laced with light tannin...
# 31       Italy  Merlot and Nero d'Avola form the base for this...
# 32       Italy  Part of the extended Calanìca series, this Gri...
# ...        ...                                                ...
# 129807   Italy  Here is yet another Roero Riserva from the suc...
# 129813   Italy  Here's a more informal and approachable expres...
# 129844   Italy  Doga delle Clavule is a neutral, mineral-drive...
# 129893   Italy  Aromas of passion fruit, hay and a vegetal not...
# 129964  France  Initially quite muted, this wine slowly develo...
#
#                          designation  points  price           province  \
# 0                       Vulkà Bianco      87    NaN  Sicily & Sardinia
# ...

# %%
wine_df['naujas_stulpelis'] = 'naujas'
wine_df
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
wine_df['naujas_stulpelis'] = wine_df['price'] * wine_df['points'] / 100
wine_df
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %% [markdown]
# ## Metodai

# %%
wine_df['price'].mean()
# Out:
# 35.363389129985535

# %%
wine_df['price'].mean()

# %%
wine_df['taster_name'].unique()
# Out:
# array(['Kerin O’Keefe', 'Roger Voss', 'Paul Gregutt',
#        'Alexander Peartree', 'Michael Schachner', 'Anna Lee C. Iijima',
#        'Virginie Boone', 'Matt Kettmann', nan, 'Sean P. Sullivan',
#        'Jim Gordon', 'Joe Czerwinski', 'Anne Krebiehl\xa0MW',
#        'Lauren Buzzeo', 'Mike DeSimone', 'Jeff Jenssen',
#        'Susan Kostrzewa', 'Carrie Dykes', 'Fiona Adams',
#        'Christina Pickard'], dtype=object)

# %%
wine_df['taster_name'].value_counts()
# Out:
# Roger Voss            25514
# Michael Schachner     15134
# Kerin O’Keefe         10776
# Virginie Boone         9537
# Paul Gregutt           9532
# Matt Kettmann          6332
# Joe Czerwinski         5147
# Sean P. Sullivan       4966
# Anna Lee C. Iijima     4415
# Jim Gordon             4177
# Anne Krebiehl MW       3685
# Lauren Buzzeo          1835
# Susan Kostrzewa        1085
# Mike DeSimone           514
# Jeff Jenssen            491
# Alexander Peartree      415
# Carrie Dykes            139
# Fiona Adams              27
# Christina Pickard         6
# Name: taster_name, dtype: int64

# %%
wine_df['description_len'] = wine_df['description'].map(len)
wine_df
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
def word_count(txt):
    return len(txt.split())

# %%
wine_df['description_len'] = wine_df['description'].map(word_count)
wine_df
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
def my_function(row):
    return str(row['country']) + ' ' + str(row['province'])

# %%
wine_df['place'] = wine_df.apply(my_function, axis = 1)
wine_df
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %% [markdown]
# ## drop NaNs

# %%
wine_df.drop_duplicates(inplace=True)

# %%
wine_df
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
wine_df[ wine_df['price'].isnull()].shape
# Out:
# (8395, 16)

# %%
wine_df.dropna(how = 'any', subset=['price', 'province']) # drop rows with NaN price, province columns
# Out:
#          country                                        description  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# 5          Spain  Blackberry and raspberry aromas show a typical...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price        province  \
# ...

# %% [markdown]
# ## groupby

# %%
grouped = wine_df.groupby(['country', 'province'])[['points','price']].mean()
grouped
# Out:
#                                points      price
# country   province
# Argentina Mendoza Province  86.765306  25.103632
#           Other             85.956522  21.404000
# Armenia   Armenia           87.500000  14.500000
# Australia Australia Other   85.467532  12.466667
#           New South Wales   87.719512  25.121951
# ...                               ...        ...
# Uruguay   Juanico           86.272727  47.545455
#           Montevideo        88.400000  27.000000
#           Progreso          86.818182  24.272727
#           San Jose          84.000000  30.000000
#           Uruguay           86.739130  22.173913
#
# [425 rows x 2 columns]

# %%
grouped.loc['Australia']
# Out:
#                       points      price
# province
# Australia Other    85.467532  12.466667
# New South Wales    87.719512  25.121951
# South Australia    89.021243  39.145701
# Tasmania           89.000000  36.527778
# Victoria           88.831683  43.070707
# Western Australia  88.930657  33.937729

# %%
wine_df.to_csv('wine_cleaned.csv')
